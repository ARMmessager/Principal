# %%
import random as random 
import matplotlib.pyplot as plt
import math
# import tkinter as tk
# from tkinter import simpledialog

def is_in():
    a = random.random()
    b = random.random()
    x = -1 + 2*a
    y = -1 + 2*b 
    L = (x**2 + b**2)**0.5
    List1.append(L)

    if L <= 1 :
        return 1
    else:
        return 0

# F = simpledialog.askstring(title="Test",
#                                   prompt="What's your Name?:")
List1 = []
F = int(input("F"))
N = 0

for i in range(F):
    N += is_in()

print((N*4/F))
print(N/F)
print(plt.hist(List1))
plt.show()
# Out:
# 3.090909090909091
# 0.7727272727272727
# (array([1., 2., 5., 6., 2., 8., 9., 5., 4., 2.]), array([0.13195208, 0.24876716, 0.36558225, 0.48239733, 0.59921242,
#        0.7160275 , 0.83284258, 0.94965767, 1.06647275, 1.18328783,
#        1.30010292]), <BarContainer object of 10 artists>)
